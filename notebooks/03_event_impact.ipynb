# %%
impact = pd.DataFrame({
    'event':['Telebirr Launch','M-Pesa Launch','Safaricom Entry','Interoperability'],
    'ACC_OWNERSHIP':[1.5,1.0,0.8,0.6],
    'USG_DIGITAL_PAYMENT':[4.0,3.5,2.0,3.0],
    'lag_months':[12,12,18,6]
})
impact
matrix = impact.set_index('event')[['ACC_OWNERSHIP','USG_DIGITAL_PAYMENT']]

plt.figure(figsize=(8,4))
sns.heatmap(matrix, annot=True, cmap='YlGnBu')
plt.title('Event-Indicator Association Matrix')
plt.savefig('reports/figures/event_heatmap.png', dpi=300)
plt.show()
