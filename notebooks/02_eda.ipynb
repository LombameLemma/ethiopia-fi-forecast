# %%
import matplotlib.pyplot as plt

access = pd.DataFrame({
    'year':[2011,2014,2017,2021,2024],
    'ownership':[14,22,35,46,49]
})

plt.figure(figsize=(8,5))
plt.plot(access['year'], access['ownership'], marker='o')
plt.title('Ethiopia Account Ownership Trajectory')
plt.xlabel('Year')
plt.ylabel('Ownership %')
plt.grid(True)
plt.savefig('reports/figures/account_trajectory.png', dpi=300)
plt.show()
events = df[df['record_type']=='event'][['event_name','event_date','category']]
events = events.sort_values('event_date')
events.head(10)
numeric = df.select_dtypes(include='number')
corr = numeric.corr()

import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=False, cmap='coolwarm')
plt.title('Indicator Correlation Heatmap')
plt.show()
